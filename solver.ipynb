# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import andlib
from scipy import misc
andlib.Init()

# %%
im = andlib.GetScreen()
plt.imshow(im)

# %%
misc.imsave("asdf.png", im)

# %%
im.shape
# Out:
# (1920L, 1080L, 4L)

# %%
1920./1080
# Out:
# 1.7777777777777777
